# %%
import pandas as pd

from config import filename_all

# %%
data = [['2020-12-31', '01,02,03,04,05,06', '01', '02', '03', '04', '05', '06', 'Thursday', 'odd-even-odd-even-odd-even', 'Even: 3, Odd: 3']]

new_df = pd.DataFrame(data, columns = ['Date', 'Winning Numbers', 'first', 'second', 'third', 'fourth', 'fifth', 'sixth', 'Day_Name', 'Odd_Even', 'Odd_Even_Dist'])

# %%
new_df
# Out:
#          Date    Winning Numbers first second third fourth fifth sixth  \
# 0  2020-12-31  01,02,03,04,05,06    01     02    03     04    05    06
#
#    Day_Name                    Odd_Even    Odd_Even_Dist
# 0  Thursday  odd-even-odd-even-odd-even  Even: 3, Odd: 3

# %%
past_df = pd.read_excel(filename_all)

# %%
past_df
# Out:
#       Draw       Date    Winning Numbers  first  second  third  fourth  fifth  \
# 0     3282 2020-12-29  09,11,23,25,31,39      9      11     23      25     31
# 1     3281 2020-12-26  15,22,23,24,34,37     15      22     23      24     34
# 2     3280 2020-12-24  09,14,16,28,33,41      9      14     16      28     33
# 3     3279 2020-12-22  01,04,05,27,28,33      1       4      5      27     28
# 4     3278 2020-12-19  06,11,15,33,34,42      6      11     15      33     34
# ...    ...        ...                ...    ...     ...    ...     ...    ...
# 2124     5 1995-04-05   2,20,28,37,41,42      2      20     28      37     41
# 2125     4 1995-03-29    1,9,25,26,37,40      1       9     25      26     37
# 2126     3 1995-03-22   5,12,14,22,30,35      5      12     14      22     30
# 2127     2 1995-03-15   8,14,24,30,36,40      8      14     24      30     36
# 2128     1 1995-03-08   4,20,22,30,34,38      4      20     22      30     34
#
# ...

# %%
past_draw = past_df['Draw'].iloc[0]

# %%
past_draw
# Out:
# 3282

# %%
new_df['Draw'] = past_draw + 1

# %%
new_df
# Out:
#          Date    Winning Numbers first second third fourth fifth sixth  \
# 0  2020-12-31  01,02,03,04,05,06    01     02    03     04    05    06
#
#    Day_Name                    Odd_Even    Odd_Even_Dist  Draw
# 0  Thursday  odd-even-odd-even-odd-even  Even: 3, Odd: 3  3283

# %%
new_df = new_df[['Draw', 'Date', 'Winning Numbers', 'first', 'second', 'third', 'fourth', 'fifth', 'sixth', 'Day_Name', 'Odd_Even', 'Odd_Even_Dist']]

# %%
new_df
# Out:
#    Draw        Date    Winning Numbers first second third fourth fifth sixth  \
# 0  3283  2020-12-31  01,02,03,04,05,06    01     02    03     04    05    06
#
#    Day_Name                    Odd_Even    Odd_Even_Dist
# 0  Thursday  odd-even-odd-even-odd-even  Even: 3, Odd: 3

# %%
new_df = new_df.append(past_df, sort = False, ignore_index = True)

# %%
new_df
# Out:
#       Draw                 Date    Winning Numbers first second third fourth  \
# 0     3283           2020-12-31  01,02,03,04,05,06    01     02    03     04
# 1     3282  2020-12-29 00:00:00  09,11,23,25,31,39     9     11    23     25
# 2     3281  2020-12-26 00:00:00  15,22,23,24,34,37    15     22    23     24
# 3     3280  2020-12-24 00:00:00  09,14,16,28,33,41     9     14    16     28
# 4     3279  2020-12-22 00:00:00  01,04,05,27,28,33     1      4     5     27
# ...    ...                  ...                ...   ...    ...   ...    ...
# 2125     5  1995-04-05 00:00:00   2,20,28,37,41,42     2     20    28     37
# 2126     4  1995-03-29 00:00:00    1,9,25,26,37,40     1      9    25     26
# 2127     3  1995-03-22 00:00:00   5,12,14,22,30,35     5     12    14     22
# 2128     2  1995-03-15 00:00:00   8,14,24,30,36,40     8     14    24     30
# 2129     1  1995-03-08 00:00:00   4,20,22,30,34,38     4     20    22     30
#
# ...
