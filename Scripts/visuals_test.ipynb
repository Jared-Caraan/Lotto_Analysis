# %%
import pandas as pd
import plotly.graph_objects as go

from config import filename_excel

# %%
df = pd.read_excel(filename_excel)

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df
# Out:
#            Date    Winning Numbers  first  second  third  fourth  fifth  sixth
# 0    14/03/2020  08,21,24,27,32,38      8      21     24      27     32     38
# 1    12/03/2020  13,17,25,27,30,41     13      17     25      27     30     41
# 2    10/03/2020  10,21,28,32,33,36     10      21     28      32     33     36
# 3    07/03/2020  03,05,09,11,14,17      3       5      9      11     14     17
# 4    05/03/2020  14,15,17,20,24,39     14      15     17      20     24     39
# ..          ...                ...    ...     ...    ...     ...    ...    ...
# 417  29/06/2017  04,08,14,21,38,40      4       8     14      21     38     40
# 418  27/06/2017  06,10,20,30,34,35      6      10     20      30     34     35
# 419  24/06/2017  02,07,13,21,40,41      2       7     13      21     40     41
# 420  22/06/2017  06,12,13,16,21,27      6      12     13      16     21     27
# 421  20/06/2017  11,12,13,14,24,25     11      12     13      14     24     25
#
# [422 rows x 8 columns]

# %%
df.describe()
# Out:
#             first      second       third      fourth       fifth       sixth
# count  422.000000  422.000000  422.000000  422.000000  422.000000  422.000000
# mean     6.246445   12.028436   18.341232   24.490521   30.744076   37.047393
# std      4.989388    6.159723    6.759328    6.638880    6.003633    4.603276
# min      1.000000    2.000000    4.000000    8.000000   12.000000   17.000000
# 25%      2.000000    7.000000   13.000000   20.000000   26.250000   35.000000
# 50%      5.000000   11.000000   18.000000   25.000000   31.000000   38.000000
# 75%      9.000000   16.000000   23.000000   30.000000   36.000000   41.000000
# max     26.000000   31.000000   38.000000   40.000000   41.000000   42.000000

# %%
df['Date'] = pd.to_datetime(df['Date'], format = '%d/%m/%Y')

# %%
df['Day_Name'] = df['Date'].dt.day_name()

# %%
filt = df['Date'] >= df['Date'].max() - pd.DateOffset(years=1)
df_year = df[filt]

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(
                x = df_year['Date'],
                y = df_year['first'],
                name = "First Winning Number",
                line_color = "deepskyblue",
                mode = "lines+markers",
                opacity = 0.8))

fig.add_trace(go.Scatter(
                x = df_year['Date'],
                y = df_year['second'],
                name = "Second Winning Number",
                line_color = "yellow",
                mode = "lines+markers",
                opacity = 0.8))

fig.add_trace(go.Scatter(
                x = df_year['Date'],
                y = df_year['third'],
                name = "Third Winning Number",
                line_color = "red",
                mode = "lines+markers",
                opacity = 0.8))

fig.add_trace(go.Scatter(
                x = df_year['Date'],
                y = df_year['fourth'],
                name = "Fourth Winning Number",
                line_color = "green",
                mode = "lines+markers",
                opacity = 0.8))

fig.add_trace(go.Scatter(
                x = df_year['Date'],
                y = df_year['fifth'],
                name = "Fifth Winning Number",
                line_color = "violet",
                mode = "lines+markers",
                opacity = 0.8))

fig.add_trace(go.Scatter(
                x = df_year['Date'],
                y = df_year['sixth'],
                name = "Sixth Winning Number",
                line_color = "black",
                mode = "lines+markers",
                opacity = 0.8))

fig.update_layout(xaxis_range=[df_year['Date'].min(), df_year['Date'].max()])

fig.update_xaxes(
    rangeslider_visible = True,
    rangeselector = dict(
        buttons = list([
            dict(count = 1, label = "1 month", step = "month", stepmode = "backward"),
            dict(count = 6, label = "6 months", step = "month", stepmode = "backward"),
            dict(step="all")
        ])
    )            
)

fig.show()
# Out:
# <div>
#
#
#             <div id="b2cac2e6-d801-456f-ae82-2997d2501adb" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b2cac2e6-d801-456f-ae82-2997d2501adb")) {
#                     Plotly.newPlot(
#                         'b2cac2e6-d801-456f-ae82-2997d2501adb',
# ...
